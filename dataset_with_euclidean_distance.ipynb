# %%
# import numpy as np
# import pandas as pd 
# import csv

# %%
# from sklearn.utils import shuffle

# raw_data = pd.read_csv('mergeddata_june22.csv')
# print(raw_data[:10])

# raw_data = raw_data.fillna(0)
# # raw_data_s = shuffle(raw_data).fillna(0)
# print(raw_data[:10])

# %%
# raw_data_shuffled = raw_data.sample(frac=1).reset_index(drop=True)
# print(raw_data_shuffled[:10])
# # print(list(raw_data_shuffled.columns.values[1:])+["Rank"])

# %%
# k = np.array([0, 1, 0.0, 0,0.0 ])
# all_zeros = not k.any()
# print(all_zeros)
# print(np.ones(shape=(1,2)))

# %%
# mat = raw_data_shuffled.as_matrix()
# print(mat.shape)

# %%
# print(mat)

# %% [markdown]
# # Use the below

# %%
# API
import numpy as np
import pandas as pd 
from scipy.special import comb

def get_partial_data_as_matrix(data, entry, shuffle=True):
    if shuffle:
        temp = data.sample(frac=1).reset_index(drop=True)
    else:
        temp = data
    return temp[:entry], list(data.columns.values) 

def generate_euclidean_data(data):
    mat = data.as_matrix() # convert dataframe into np matrix
#     print(mat.shape)  
    new_mat = np.zeros(shape=(int(comb(mat.shape[0], 2)), mat.shape[1]))
#     print(new_mat.shape)

    count = 0 
    for i in range(mat.shape[0]):
        for j in range(i):
            # calculate rank as entry 1 price > entry 2 price ? 1: 0
            # new_mat[count] = np.concatenate((mat[i,1:], mat[j,1:], np.asarray([1 if mat[i,0] > mat[j,0] else 0]))) 
            new_mat[count] = np.concatenate((mat[i,1:] - mat[j,1:], np.asarray([1 if mat[i,0] > mat[j,0] else 0])))
            count += 1
    return new_mat

def normalize_data(mat):
    max_values = np.amax(mat, axis=0)
    all_zeros = not max_values.any()
    if all_zeros:
        max_shape = max_values.shape
        max_values = np.ones(shape=max_shape)
    return mat/max_values

def convert_to_dataframe(mat, col_names):
    return pd.DataFrame(data=mat, columns=col_names)    

def save_to_csv(df, path):
    df.to_csv(path)
    
def generated_euclidean_dataframe(data, entry, path, shuffle=True):
    filtered_data = data.fillna(0)
    temp, col_names = get_partial_data_as_matrix(filtered_data, entry, shuffle=shuffle)
    mat = generate_euclidean_data(temp)
    normalized_mat = normalize_data(mat)
    normalized_df = convert_to_dataframe(normalized_mat, col_names[1:]+['Rank'])
    save_to_csv(normalized_df, path)
    return normalized_df

# %% [markdown]
# # Example

# %%
raw_data = pd.read_csv('mergeddata_june22.csv')
# print(raw_data[:10])

# %%
# arguments are:  raw_data as a dataframe,  number of entries to select from raw_data, path name to the file saved
test_df = generated_euclidean_dataframe(raw_data, 10, 'euclidean_data10.csv')
test_df
# Out:
#     Bedrooms  Bathrooms      Size     Crime   Transit  Shopping    Health  \
# 0        1.0        0.5  1.000000 -0.137634 -0.050725 -0.055242  0.577287
# 1        0.0        0.0  0.000000 -1.894624  0.949275  0.944758 -2.044164
# 2       -1.0       -0.5 -1.000000 -1.756989  1.000000  1.000000 -2.621451
# 3        0.5        0.0  0.000000 -1.969892  0.204348  0.746336 -1.823344
# 4       -0.5       -0.5 -1.000000 -1.832258  0.255072  0.801578 -2.400631
# 5        0.5        0.0  0.000000 -0.075269 -0.744928 -0.198422  0.220820
# 6        0.0        0.0  0.083333 -1.969892  0.204348  0.746336 -1.823344
# 7       -1.0       -0.5 -0.916667 -1.832258  0.255072  0.801578 -2.400631
# 8        0.0        0.0  0.083333 -0.075269 -0.744928 -0.198422  0.220820
# 9       -0.5        0.0  0.083333  0.000000  0.000000  0.000000  0.000000
# 10       1.0        1.0  0.833333 -1.969892  0.204348  0.746336 -1.823344
# 11       0.0        0.5 -0.166667 -1.832258  0.255072  0.801578 -2.400631
# 12       1.0        1.0  0.833333 -0.075269 -0.744928 -0.198422  0.220820
# 13       0.5        1.0  0.833333  0.000000  0.000000  0.000000  0.000000
# 14       1.0        1.0  0.750000  0.000000  0.000000  0.000000  0.000000
# 15       0.5        0.0  0.083333 -1.849462  0.856522  0.864713 -1.044164
# 16      -0.5       -0.5 -0.916667 -1.711828  0.907246  0.919955 -1.621451
# 17       0.5        0.0  0.083333  0.045161 -0.092754 -0.080045  1.000000
# 18       0.0        0.0  0.083333  0.120430  0.652174  0.118377  0.779180
# 19       0.5        0.0  0.000000  0.120430  0.652174  0.118377  0.779180
# 20      -0.5       -1.0 -0.750000  0.120430  0.652174  0.118377  0.779180
# 21       0.5        0.0  0.083333 -1.834409  0.785507  0.936866 -1.444795
# 22      -0.5       -0.5 -0.916667 -1.696774  0.836232  0.992108 -2.022082
# 23       0.5        0.0  0.083333  0.060215 -0.163768 -0.007892  0.599369
# 24       0.0        0.0  0.083333  0.135484  0.581159  0.190530  0.378549
# 25       0.5        0.0  0.000000  0.135484  0.581159  0.190530  0.378549
# 26      -0.5       -1.0 -0.750000  0.135484  0.581159  0.190530  0.378549
# 27       0.0        0.0  0.000000  0.015054 -0.071014  0.072153 -0.400631
# 28       0.5        0.5  0.500000 -0.969892  0.550725  0.015784 -2.066246
# 29      -0.5        0.0 -0.500000 -0.832258  0.601449  0.071026 -2.643533
# 30       0.5        0.5  0.500000  0.924731 -0.398551 -0.928974 -0.022082
# 31       0.0        0.5  0.500000  1.000000  0.346377 -0.730552 -0.242902
# 32       0.5        0.5  0.416667  1.000000  0.346377 -0.730552 -0.242902
# 33      -0.5       -0.5 -0.333333  1.000000  0.346377 -0.730552 -0.242902
# 34       0.0        0.5  0.416667  0.879570 -0.305797 -0.848929 -1.022082
# 35       0.0        0.5  0.416667  0.864516 -0.234783 -0.921082 -0.621451
# 36       0.5        0.5  0.166667 -1.516129 -0.355072  0.682074 -2.400631
# 37      -0.5        0.0 -0.833333 -1.378495 -0.304348  0.737317 -2.977918
# 38       0.5        0.5  0.166667  0.378495 -1.304348 -0.262683 -0.356467
# 39       0.0        0.5  0.166667  0.453763 -0.559420 -0.064262 -0.577287
# 40       0.5        0.5  0.083333  0.453763 -0.559420 -0.064262 -0.577287
# 41      -0.5       -0.5 -0.666667  0.453763 -0.559420 -0.064262 -0.577287
# 42       0.0        0.5  0.083333  0.333333 -1.211594 -0.182638 -1.356467
# 43       0.0        0.5  0.083333  0.318280 -1.140580 -0.254791 -0.955836
# 44       0.0        0.0 -0.333333 -0.546237 -0.905797  0.666291 -0.334385
#
#     Entertainment  Community  Diversity  ...   size*crime  size*transit  \
# 0       -0.105405  -0.250832  -0.347774  ...     1.000000      0.481648
# 1        0.894595   0.304107  -0.567990  ...    -0.531726      0.611491
# 2        1.000000   0.554939  -0.220217  ...    -1.531726      0.129843
# 3        0.808108   0.749168  -0.025271  ...    -0.552850      0.131634
# 4        0.913514   1.000000   0.322503  ...    -1.552850     -0.350014
# 5       -0.086486   0.445061   0.542720  ...    -0.021124     -0.479857
# 6        0.808108   0.749168  -0.025271  ...    -0.552145      0.201925
# 7        0.913514   1.000000   0.322503  ...    -1.552145     -0.279723
# 8       -0.086486   0.445061   0.542720  ...    -0.020419     -0.409566
# 9        0.000000   0.000000   0.000000  ...     0.000705      0.070291
# 10       0.808108   0.749168  -0.025271  ...    -0.545797      0.834542
# 11       0.913514   1.000000   0.322503  ...    -1.545797      0.352894
# 12      -0.086486   0.445061   0.542720  ...    -0.014071      0.223051
# 13       0.000000   0.000000   0.000000  ...     0.007053      0.702908
# 14       0.000000   0.000000   0.000000  ...     0.006348      0.632617
# 15       0.379730   0.248613  -0.119134  ...    -0.512704      0.692168
# 16       0.485135   0.499445   0.228640  ...    -1.512704      0.210520
# 17      -0.514865  -0.055494   0.448857  ...     0.019022      0.080677
# 18      -0.428378  -0.500555  -0.093863  ...     0.040147      0.560534
# 19      -0.428378  -0.500555  -0.093863  ...     0.039441      0.490243
# 20      -0.428378  -0.500555  -0.093863  ...     0.033093     -0.142374
# 21       0.675676   0.631521  -0.856799  ...    -0.507774      0.638786
# 22       0.781081   0.882353  -0.509025  ...    -1.507774      0.157138
# 23      -0.218919   0.327414  -0.288809  ...     0.023953      0.027295
# 24      -0.132432  -0.117647  -0.831528  ...     0.045077      0.507152
# 25      -0.132432  -0.117647  -0.831528  ...     0.044371      0.436861
# 26      -0.132432  -0.117647  -0.831528  ...     0.038024     -0.195756
# 27       0.295946   0.382908  -0.737665  ...     0.004930     -0.053382
# 28       0.256757  -0.267481  -0.228640  ...     0.013150      1.000000
# 29       0.362162  -0.016648   0.119134  ...    -0.986850      0.518352
# 30      -0.637838  -0.571587   0.339350  ...     0.544876      0.388509
# 31      -0.551351  -1.016648  -0.203369  ...     0.566000      0.868366
# 32      -0.551351  -1.016648  -0.203369  ...     0.565295      0.798075
# 33      -0.551351  -1.016648  -0.203369  ...     0.558947      0.165458
# 34      -0.122973  -0.516093  -0.109507  ...     0.525854      0.307832
# 35      -0.418919  -0.899001   0.628159  ...     0.520924      0.361214
# 36       0.094595   0.163152   0.143201  ...    -0.381571     -0.208465
# 37       0.200000   0.413984   0.490975  ...    -1.381571     -0.690113
# 38      -0.800000  -0.140954   0.711191  ...     0.150156     -0.819956
# 39      -0.713514  -0.586016   0.168472  ...     0.171280     -0.340099
# 40      -0.713514  -0.586016   0.168472  ...     0.170574     -0.410389
# 41      -0.713514  -0.586016   0.168472  ...     0.164227     -1.043007
# 42      -0.285135  -0.085461   0.262335  ...     0.131133     -0.900633
# 43      -0.581081  -0.468368   1.000000  ...     0.126203     -0.847251
# 44      -0.162162   0.430633   0.371841  ...    -0.394721     -1.208465
#
#     size*health  size*shopping  size*entertainment  size*community  \
# 0      1.000000       0.060920            0.018784       -0.023442
# 1     -0.304190       0.420919            0.363729        0.115281
# 2     -1.304190       0.359999            0.344945        0.138723
# 3     -0.271330       0.332516            0.328565        0.283996
# 4     -1.271330       0.271596            0.309781        0.307438
# 5      0.032860      -0.088403           -0.035164        0.168715
# 6     -0.254794       0.399264            0.395708        0.353252
# 7     -1.254794       0.338345            0.376925        0.376694
# 8      0.049396      -0.021655            0.031979        0.237971
# 9      0.016536       0.066748            0.067144        0.069256
# 10    -0.105972       1.000000            1.000000        0.976558
# 11    -1.105972       0.939080            0.981216        1.000000
# 12     0.198218       0.579081            0.636271        0.861277
# 13     0.165358       0.667484            0.671435        0.692562
# 14     0.148822       0.600736            0.604292        0.623306
# 15    -0.119488       0.460810            0.192459        0.131823
# 16    -1.119488       0.399890            0.173675        0.155265
# 17     0.184702       0.039891           -0.171270        0.016541
# 18     0.151842       0.128294           -0.136106       -0.152173
# 19     0.135306       0.061545           -0.203249       -0.221430
# 20    -0.013516      -0.539190           -0.807541       -0.844735
# 21    -0.189059       0.498323            0.332874        0.301209
# 22    -1.189059       0.437403            0.314090        0.324651
# 23     0.115132       0.077404           -0.030855        0.185928
# 24     0.082272       0.165807            0.004309        0.017213
# 25     0.065736       0.099058           -0.062834       -0.052043
# 26    -0.083087      -0.501677           -0.667126       -0.675349
# 27    -0.069570       0.037513            0.140415        0.169386
# 28    -0.244468       0.081495            0.282709       -0.071897
# 29    -1.244468       0.020575            0.263925       -0.048455
# 30     0.059723      -0.339424           -0.081020       -0.187178
# 31     0.026862      -0.251021           -0.045856       -0.355893
# 32     0.010327      -0.317769           -0.112999       -0.425149
# 33    -0.138496      -0.918505           -0.717291       -1.048455
# 34    -0.124980      -0.379315            0.090250       -0.203719
# 35    -0.055409      -0.416828           -0.050165       -0.373106
# 36    -0.352847       0.427823            0.075885        0.126187
# 37    -1.352847       0.366903            0.057101        0.149629
# 38    -0.048657       0.006904           -0.287844        0.010906
# 39    -0.081517       0.095307           -0.252680       -0.157809
# 40    -0.098053       0.028558           -0.319823       -0.227065
# 41    -0.246875      -0.572177           -0.924115       -0.850371
# 42    -0.233359      -0.032987           -0.116574       -0.005635
# 43    -0.163789      -0.070500           -0.256989       -0.175022
# 44    -0.108379       0.346328           -0.206824        0.198084
#
#     size*diversity  size*school  size*employment  Rank
# 0         0.411202    -0.370929         0.684968   1.0
# 1        -0.272339     0.063332         0.096101   0.0
# 2        -0.683541     0.434261        -0.588866   0.0
# 3        -0.012117    -0.092170         0.167419   1.0
# 4        -0.423319     0.278759        -0.517549   1.0
# 5         0.260222    -0.155502         0.071317   1.0
# 6         0.061861    -0.043648         0.250677   1.0
# 7        -0.349341     0.327281        -0.434291   0.0
# 8         0.334200    -0.106980         0.154576   1.0
# 9         0.073978     0.048522         0.083258   0.0
# 10        0.727661     0.393050         1.000000   1.0
# 11        0.316459     0.763979         0.315032   1.0
# 12        1.000000     0.329718         0.903899   1.0
# 13        0.739778     0.485220         0.832581   1.0
# 14        0.665800     0.436698         0.749323   1.0
# 15        0.009343     0.165528         0.217624   1.0
# 16       -0.401859     0.536457        -0.467344   1.0
# 17        0.281681     0.102196         0.121522   1.0
# 18        0.021459     0.257698         0.050205   0.0
# 19       -0.052518     0.209176        -0.033053   1.0
# 20       -0.718319    -0.227522        -0.782376   0.0
# 21       -0.403399     0.072488         0.142664   1.0
# 22       -0.814601     0.443417        -0.542304   1.0
# 23       -0.131060     0.009156         0.046562   1.0
# 24       -0.391282     0.164658        -0.024755   0.0
# 25       -0.465260     0.116136        -0.108013   1.0
# 26       -1.131060    -0.320562        -0.857336   0.0
# 27       -0.412741    -0.093040        -0.074960   0.0
# 28        0.236565     0.629071        -0.089324   0.0
# 29       -0.174637     1.000000        -0.774292   0.0
# 30        0.508904     0.565739        -0.185426   0.0
# 31        0.248682     0.721241        -0.256743   0.0
# 32        0.174704     0.672719        -0.340001   0.0
# 33       -0.491096     0.236021        -1.089324   0.0
# 34        0.227223     0.463543        -0.306948   0.0
# 35        0.639964     0.556583        -0.231988   0.0
# 36        0.243588    -0.032085        -0.284070   1.0
# 37       -0.167614     0.338844        -0.969037   0.0
# 38        0.515927    -0.095417        -0.380171   1.0
# 39        0.255705     0.060085        -0.451489   0.0
# 40        0.181727     0.011563        -0.534747   1.0
# 41       -0.484073    -0.425135        -1.284070   0.0
# 42        0.234246    -0.197613        -0.501693   0.0
# 43        0.646987    -0.104572        -0.426733   0.0
# 44        0.007023    -0.661156        -0.194745   1.0
#
# [45 rows x 22 columns]
