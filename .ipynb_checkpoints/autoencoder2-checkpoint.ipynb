# %%
import tensorflow as tf 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from __future__ import division, print_function, absolute_import

# %%
df = pd.read_csv('autoencoder.csv')
df
# Out:
#       Bedrooms  Bathrooms  Size  neighbour
# 0            2          2   950   0.756977
# 1            3          3  1299   0.766887
# 2            3          3  1200   0.941384
# 3            1          2   680   0.756977
# 4            2          2   890   0.756977
# 5            3          2  1100   0.766887
# 6            3          2  1299   0.766887
# 7            3          3  1400   0.941384
# 8            2          2   810   0.941384
# 9            2          2   800   0.941384
# 10           3          3  1399   0.941384
# 11           1          2   599   0.766887
# 12           2          2   890   0.756977
# 13           3          3  1299   0.941384
# 14           2          1   720   0.756977
# 15           2          3   890   0.941384
# 16           2          2   870   0.756977
# 17           3          3  1200   0.766887
# 18           3          3  1300   0.941384
# 19           3          3  1299   0.766887
# 20           2          2   870   0.756977
# 21           3          2  1199   0.941384
# 22           2          2   799   0.756977
# 23           1          2   560   0.766887
# 24           2          2   799   0.756977
# 25           2          3   999   0.941384
# 26           2          2   799   0.766887
# 27           3          2  1199   0.756977
# 28           3          3  1399   0.766887
# 29           2          2   899   0.766887
# ...        ...        ...   ...        ...
# 3509         1          1   599   0.840193
# 3510         2          2   860   0.478869
# 3511         2          2   799   0.557622
# 3512         3          2   999   0.478869
# 3513         2          2   799   0.557622
# 3514         2          2   799   0.898093
# 3515         3          2   990   0.557622
# 3516         2          3   899   0.569773
# 3517         3          3  1099   0.071133
# 3518         4          3  1499   0.569773
# 3519         2          3  1199   0.347398
# 3520         2          2  1099   0.898093
# 3521         3          3  1299   0.487021
# 3522         2          2   799   0.557622
# 3523         2          2   999   0.497170
# 3524         2          2   799   0.912678
# 3525         2          1   699   0.516084
# 3526         2          1   750   0.347398
# 3527         3          2  1299   0.448108
# 3528         2          3  1199   0.058990
# 3529         2          2   999   0.897528
# 3530         1          1   599   0.249973
# 3531         2          2   799   0.478869
# 3532         3          3  1199   0.569773
# 3533         2          2   999   0.557622
# 3534         2          2   799   0.579558
# 3535         2          1   670   0.361804
# 3536         3          2  1299   0.516084
# 3537         2          2   799   0.898093
# 3538         1          1   450   0.516084
#
# [3539 rows x 4 columns]

# %%
bed = list(df.as_matrix()[:,0])
bath = list(df.as_matrix()[:,1])
sizes = list(df.as_matrix()[:,2])
print(max(sizes))
neigh = list(df.as_matrix()[:,3])
# Out:
# 1599.0

# %%
def get_data(path):
    df = pd.read_csv(path)
    matrix_df = df.as_matrix()
    mat = matrix_df[:,:]
    where_are_NaNs = np.isnan(mat)
    mat[where_are_NaNs] = 0
    maximums = np.amax(mat, axis=0)
    print(maximums)
    mat = mat/maximums
    return mat

# %%
mat = get_data("autoencoder.csv")
print(mat[:5])
# Out:
# [  4.00000000e+00   4.00000000e+00   1.59900000e+03   9.61952329e-01]
# [[ 0.5         0.5         0.59412133  0.7869169 ]
#  [ 0.75        0.75        0.81238274  0.79721929]
#  [ 0.75        0.75        0.75046904  0.97861773]
#  [ 0.25        0.5         0.42526579  0.7869169 ]
#  [ 0.5         0.5         0.55659787  0.7869169 ]]

# %%
def next_batch(mat, index, size):
    if index + size <= mat.shape[0]:
        return index+size, mat[index:index+size]
    else:
        return index+size-mat.shape[0], np.concatenate((mat[index:], mat[:index+size-mat.shape[0]]), axis=0)

# %%
learning_rate = 0.0001
training_epochs = 1000
batch_size = 50
display_step = 100
examples_to_show = 10
index = 0

# %%
n_hidden_1 = 8
n_hidden_2 = 4
n_hidden_3 = 1
n_input = 4

# %%
X = tf.placeholder("float", [None, n_input])

# %%
weights = {
    'encoder_h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'encoder_h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'encoder_h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'decoder_h1': tf.Variable(tf.random_normal([n_hidden_3, n_hidden_2])),
    'decoder_h2': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_1])),
    'decoder_h3': tf.Variable(tf.random_normal([n_hidden_1, n_input]))
}

biases = {
    'encoder_b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'encoder_b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'encoder_b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'decoder_b1': tf.Variable(tf.random_normal([n_hidden_2])),
    'decoder_b2': tf.Variable(tf.random_normal([n_hidden_1])),
    'decoder_b3': tf.Variable(tf.random_normal([n_input]))
}

# %%
bed_weights = weights['encoder_h1'][0]
bath_weights = weights['encoder_h1'][1]
size_weights = weights['encoder_h1'][2]
neigh_weights = weights['encoder_h1'][3]

# %%
bed_penalty = 2.621724506
bath_penalty = 4.563851847
size_penalty = 2.205301921
neigh_penalty = 3

# %%
def encoder(x):
    layer_1 = tf.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']), biases['encoder_b1']))
    layer_2 = tf.sigmoid(tf.add(tf.matmul(layer_1, weights['encoder_h2']), biases['encoder_b2']))
    layer_3 = tf.sigmoid(tf.add(tf.matmul(layer_2, weights['encoder_h3']), biases['encoder_b3']))
    return layer_3

def decoder(x):
    layer_1 = tf.sigmoid(tf.add(tf.matmul(x, weights['decoder_h1']), biases['decoder_b1']))
    layer_2 = tf.sigmoid(tf.add(tf.matmul(layer_1, weights['decoder_h2']), biases['decoder_b2']))
    layer_3 = tf.sigmoid(tf.add(tf.matmul(layer_2, weights['decoder_h3']), biases['decoder_b3']))
    return layer_3

# %%
# Construct model 
encoder_op = encoder(X)
decoder_op = decoder(encoder_op)

# %%
# Prediction 
y_pred = decoder_op 
y_true = X

# %%
# loss and optimizer 
cost = 10000*tf.reduce_mean(tf.pow(y_true - y_pred, 2)) + 0.07*(bed_penalty*tf.reduce_sum(tf.abs(bed_weights)) + bath_penalty*tf.reduce_sum(tf.abs(bath_weights))
+ neigh_penalty*tf.reduce_sum(tf.abs(neigh_weights)) + size_penalty*tf.reduce_sum(tf.abs(size_weights)))

optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(cost)

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    total_c = []
    total_batch = int(mat.shape[0]/batch_size)
    
    for epoch in range(training_epochs):
        for i in range(total_batch):
            index, batch_xs = next_batch(mat, index, batch_size)
            _, c = sess.run([optimizer, cost], feed_dict={X: batch_xs})
         
        total_c.append(c)
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1),"cost=", "{:.9f}".format(c))
    print("Optimization Finished!")
    
    score = sess.run(encoder_op, feed_dict={X: mat})
    scores = list(score)

plt.plot(total_c)
# Out:
# Epoch: 0001 cost= 1337.182250977
# Epoch: 0101 cost= 334.995117188
# Epoch: 0201 cost= 448.503906250
# Epoch: 0301 cost= 466.040191650
# Epoch: 0401 cost= 374.671539307
# Epoch: 0501 cost= 481.239898682
# Epoch: 0601 cost= 442.512817383
# Epoch: 0701 cost= 349.449890137
# Epoch: 0801 cost= 400.520874023
# Epoch: 0901 cost= 213.663208008
# Optimization Finished!

# %%
x_line = range(1,mat.shape[0]+1)
plt.figure(figsize=(50, 20))
size_max = max(sizes)
print(size_max)
bed_max = max(bed)
bath_max = max(bath)
neigh_max = max(neigh)
score_max = max(scores)
plt.plot(x_line[1000:1300], scores[1000:1300], x_line[1000:1300], [com/size_max-0.2 for com in sizes][1000:1300], 'k')
# Out:
# 1599.0
# [<matplotlib.lines.Line2D at 0x1a0258e80>,
#  <matplotlib.lines.Line2D at 0x1a0263080>]

# %%
print(scores)
# Out:
# [array([ 0.38052258], dtype=float32), array([ 0.63754696], dtype=float32), array([ 0.58206159], dtype=float32), array([ 0.22895762], dtype=float32), array([ 0.36683291], dtype=float32), array([ 0.52601856], dtype=float32), array([ 0.56933129], dtype=float32), array([ 0.62267452], dtype=float32), array([ 0.3039611], dtype=float32), array([ 0.30190632], dtype=float32), array([ 0.62248176], dtype=float32), array([ 0.21444811], dtype=float32), array([ 0.36683291], dtype=float32), array([ 0.60266328], dtype=float32), array([ 0.26871151], dtype=float32), array([ 0.39338678], dtype=float32), array([ 0.36232269], dtype=float32), array([ 0.61901301], dtype=float32), array([ 0.60286653], dtype=float32), array([ 0.63754696], dtype=float32), array([ 0.36232269], dtype=float32), array([ 0.50644106], dtype=float32), array([ 0.34655437], dtype=float32), array([ 0.20864053], dtype=float32), array([ 0.34655437], dtype=float32), array([ 0.41971254], dtype=float32), array([ 0.34409258], dtype=float32), array([ 0.55012888], dtype=float32), array([ 0.6552217], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.46713918], dtype=float32), array([ 0.63754696], dtype=float32), array([ 0.32077771], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.25437686], dtype=float32), array([ 0.34240419], dtype=float32), array([ 0.54789352], dtype=float32), array([ 0.56933129], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.6552217], dtype=float32), array([ 0.50644106], dtype=float32), array([ 0.57147229], dtype=float32), array([ 0.32271007], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.58184886], dtype=float32), array([ 0.39185771], dtype=float32), array([ 0.58995616], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.57147229], dtype=float32), array([ 0.58393651], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.6552217], dtype=float32), array([ 0.38930804], dtype=float32), array([ 0.32271007], dtype=float32), array([ 0.50644106], dtype=float32), array([ 0.34468395], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.50559992], dtype=float32), array([ 0.55829853], dtype=float32), array([ 0.43593979], dtype=float32), array([ 0.39185771], dtype=float32), array([ 0.48385614], dtype=float32), array([ 0.4364756], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.32271007], dtype=float32), array([ 0.53205216], dtype=float32), array([ 0.54789352], dtype=float32), array([ 0.6283012], dtype=float32), array([ 0.58995616], dtype=float32), array([ 0.54789352], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.50559992], dtype=float32), array([ 0.55170333], dtype=float32), array([ 0.38930804], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.32271007], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.32271007], dtype=float32), array([ 0.48277825], dtype=float32), array([ 0.50321072], dtype=float32), array([ 0.56065369], dtype=float32), array([ 0.43903843], dtype=float32), array([ 0.54789352], dtype=float32), array([ 0.55170333], dtype=float32), array([ 0.59383553], dtype=float32), array([ 0.48277825], dtype=float32), array([ 0.28330213], dtype=float32), array([ 0.59199458], dtype=float32), array([ 0.38930804], dtype=float32), array([ 0.38930804], dtype=float32), array([ 0.47652972], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.36887154], dtype=float32), array([ 0.17739765], dtype=float32), array([ 0.50321072], dtype=float32), array([ 0.39185771], dtype=float32), array([ 0.38188326], dtype=float32), array([ 0.50321072], dtype=float32), array([ 0.50321072], dtype=float32), array([ 0.55012888], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.36635712], dtype=float32), array([ 0.30170143], dtype=float32), array([ 0.48033375], dtype=float32), array([ 0 ...

# %%
def save_to_csv(df, path):
    df.to_csv(path)
def convert_to_dataframe(mat):
    return pd.DataFrame(data=mat)
new = convert_to_dataframe(scores)
save_to_csv(new, 'new_scores.csv')
